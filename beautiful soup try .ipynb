# %% [markdown]
# # beautiful soup try

# %%
import requests

# %%
love=requests.get("https://cuchd.blackboard.com/ultra/course")

# %%
love.text
# Out:
# '<!DOCTYPE HTML >\n<html  lang="en-US">\n <head>\n  <title>Blackboard Learn</title>\n  <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n  <meta id="request-method" name="request-method" content="GET">\n  <meta name="author" content="Blackboard">\n  <meta name="copyright" content="&copy; 1997-2021 Blackboard Inc. All Rights Reserved. U.S. Patent No. 7,493,396 and 7,558,853. Additional Patents Pending.">\n  <meta name="keywords" content="Blackboard">\n  <meta http-equiv="Pragma" content="no-cache">\n  <meta http-equiv="Expires" content="-1">\n      <meta name="viewport" content="width=device-width, initial-scale=1.0"/>\n    \n<script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"232bf20b67",applicationID:"616660978"};window.NREUM||(NREUM={}),__nr_require=function(e,t,n){function r(n){if(!t[n]){var i=t[n]={exports:{}};e[n][0].call(i.exports,function(t){var i=e[n][1][t];return r(i||t)},i,i.exports)}return t[n].exports}if("function"==type
# ...

# %%
import bs4

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(love.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE HTML>
# <html lang="en-US">
# <head>
# <title>Blackboard Learn</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="GET" id="request-method" name="request-method"/>
# <meta content="Blackboard" name="author"/>
# <meta content="© 1997-2021 Blackboard Inc. All Rights Reserved. U.S. Patent No. 7,493,396 and 7,558,853. Additional Patents Pending." name="copyright"/>
# <meta content="Blackboard" name="keywords"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="-1" http-equiv="Expires"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# ...

# %%
title =soup.select('title')

# %%
title
# Out:
# [<title>Blackboard Learn</title>]

# %%
title[0].getText()
# Out:
# 'Blackboard Learn'

# %%
heading=soup.select('h1')

# %%
para
# Out:
# [<h1 class="login-logo new-logo">
#  <span>Blackboard Learn ™</span>
#  <img alt="" src="/images/ci/logos/bb-corp-logo.png"/>
#  </h1>]

# %%
soup.select('p')[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-51-fa056629fa81> in <module>
# ----> 1 soup.select('p')[0]
#
# IndexError: list index out of range

# %%
soup.select('#id="_17589_1"')
# Out:
# ---------------------------------------------------------------------------
# SelectorSyntaxError                       Traceback (most recent call last)
# <ipython-input-53-e7d1f5c3c888> in <module>
# ----> 1 soup.select('#id="_17589_1"')
#
# ~\anaconda3\lib\site-packages\bs4\element.py in select(self, selector, namespaces, limit, **kwargs)
#    1867             )
#    1868
# -> 1869         results = soupsieve.select(selector, self, namespaces, limit, **kwargs)
#    1870
#    1871         # We do this because it's more consistent and because
#
# ~\anaconda3\lib\site-packages\soupsieve\__init__.py in select(select, tag, namespaces, limit, flags, **kwargs)
#      96     """Select the specified tags."""
#      97
# ---> 98     return compile(select, namespaces, flags, **kwargs).select(tag, limit)
#      99
#     100
#
# ~\anaconda3\lib\site-packages\soupsieve\__init__.py in compile(pattern, namespaces, flags, **kwargs)
#      60         return pattern
#      61
# ...

# %%
res=requests.get("https://en.wikipedia.org/wiki/Isaac_Newton")

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Isaac Newton - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"76fee549-2bef-456a-9316-14589796b9c1","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Isaac_Newton","wgTitle":"Isaac Newton","wgCurRevisionId":1014153583,"wgRevisionId":1014153583,"wgArticleId":14627,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia articles needing page number citations from August 2014","All articles with dead external links","Articles with dead external links from June 2017","Artic
# ...

# %%
sup=BeautifulSoup(res.text,"lxml")

# %%
sup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Isaac Newton - Wikipedia</title>
# ...

# %%
sup.select(".toctext")  # use . to cllass name getting
# Out:
# [<span class="toctext">Life</span>,
#  <span class="toctext">Early life</span>,
#  <span class="toctext">Middle years</span>,
#  <span class="toctext">Mathematics</span>,
#  <span class="toctext">Optics</span>,
#  <span class="toctext">Mechanics and gravitation</span>,
#  <span class="toctext">Classification of cubics</span>,
#  <span class="toctext">Later life</span>,
#  <span class="toctext">Personal relations</span>,
#  <span class="toctext">Death</span>,
#  <span class="toctext">After death</span>,
#  <span class="toctext">Fame</span>,
#  <span class="toctext">Commemorations</span>,
#  <span class="toctext">Religious views</span>,
#  <span class="toctext">Effect on religious thought</span>,
#  <span class="toctext">Occult</span>,
#  <span class="toctext">Alchemy</span>,
#  <span class="toctext">Enlightenment philosophers</span>,
#  <span class="toctext">Apple incident</span>,
#  <span class="toctext">Works</span>,
#  <span class="toctext">Published in his lifetime</span>,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-9a6b51adbd13> in <module>
# ----> 1 sup.select(".toctext").getText
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2171     def __getattr__(self, key):
#    2172         """Raise a helpful exception to explain a common code fix."""
# -> 2173         raise AttributeError(
#    2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# AttributeError: ResultSet object has no attribute 'getText'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
for i in range(0,10):
    
    print(sup.select(".toctext")[i].text)
# Out:
# Life
# Early life
# Middle years
# Mathematics
# Optics
# Mechanics and gravitation
# Classification of cubics
# Later life
# Personal relations
# Death

# %%
listl=[]
for i in range(0,10):
    
    listl.append(sup.select(".toctext")[i].text)

# %%
listl
# Out:
# ['Life',
#  'Early life',
#  'Middle years',
#  'Mathematics',
#  'Optics',
#  'Mechanics and gravitation',
#  'Classification of cubics',
#  'Later life',
#  'Personal relations',
#  'Death']
